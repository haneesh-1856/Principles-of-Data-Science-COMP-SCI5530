01-01-01-23.wav
#   inflating: dataset/Actor_23/03-01-06-01-01-02-23.wav
#   inflating: dataset/Actor_23/03-01-06-01-02-01-23.wav
#   inflating: dataset/Actor_23/03-01-06-01-02-02-23.wav
#   inflating: dataset/Actor_23/03-01-06-02-01-01-23.wav
#   inflating: dataset/Actor_23/03-01-06-02-01-02-23.wav
#   inflating: dataset/Actor_23/03-01-06-02-02-01-23.wav
#   inflating: dataset/Actor_23/03-01-06-02-02-02-23.wav
#   inflating: dataset/Actor_23/03-01-07-01-01-01-23.wav
#   inflating: dataset/Actor_23/03-01-07-01-01-02-23.wav
#   inflating: dataset/Actor_23/03-01-07-01-02-01-23.wav
#   inflating: dataset/Actor_23/03-01-07-01-02-02-23.wav
#   inflating: dataset/Actor_23/03-01-07-02-01-01-23.wav
#   inflating: dataset/Actor_23/03-01-07-02-01-02-23.wav
#   inflating: dataset/Actor_23/03-01-07-02-02-01-23.wav
#   inflating: dataset/Actor_23/03-01-07-02-02-02-23.wav
#   inflating: dataset/Actor_23/03-01-08-01-01-01-23.wav
#   inflating: dataset/Actor_23/03-01-08-01-01-02-23.wav
#   inflating: dataset/Actor_23/03-01-08-01-02-01-23.wav
#   inflating: dataset/Actor_23/03-01-08-01-02-02-23.wav
#   inflating: dataset/Actor_23/03-01-08-02-01-01-23.wav
#   inflating: dataset/Actor_23/03-01-08-02-01-02-23.wav
#   inflating: dataset/Actor_23/03-01-08-02-02-01-23.wav
#   inflating: dataset/Actor_23/03-01-08-02-02-02-23.wav
#    creating: dataset/Actor_24/
#   inflating: dataset/Actor_24/03-01-01-01-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-01-01-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-01-01-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-01-01-02-02-24.wav
#   inflating: dataset/Actor_24/03-01-02-01-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-02-01-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-02-01-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-02-01-02-02-24.wav
#   inflating: dataset/Actor_24/03-01-02-02-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-02-02-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-02-02-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-02-02-02-02-24.wav
#   inflating: dataset/Actor_24/03-01-03-01-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-03-01-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-03-01-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-03-01-02-02-24.wav
#   inflating: dataset/Actor_24/03-01-03-02-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-03-02-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-03-02-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-03-02-02-02-24.wav
#   inflating: dataset/Actor_24/03-01-04-01-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-04-01-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-04-01-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-04-01-02-02-24.wav
#   inflating: dataset/Actor_24/03-01-04-02-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-04-02-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-04-02-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-04-02-02-02-24.wav
#   inflating: dataset/Actor_24/03-01-05-01-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-05-01-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-05-01-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-05-01-02-02-24.wav
#   inflating: dataset/Actor_24/03-01-05-02-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-05-02-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-05-02-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-05-02-02-02-24.wav
#   inflating: dataset/Actor_24/03-01-06-01-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-06-01-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-06-01-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-06-01-02-02-24.wav
#   inflating: dataset/Actor_24/03-01-06-02-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-06-02-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-06-02-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-06-02-02-02-24.wav
#   inflating: dataset/Actor_24/03-01-07-01-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-07-01-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-07-01-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-07-01-02-02-24.wav
#   inflating: dataset/Actor_24/03-01-07-02-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-07-02-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-07-02-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-07-02-02-02-24.wav
#   inflating: dataset/Actor_24/03-01-08-01-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-08-01-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-08-01-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-08-01-02-02-24.wav
#   inflating: dataset/Actor_24/03-01-08-02-01-01-24.wav
#   inflating: dataset/Actor_24/03-01-08-02-01-02-24.wav
#   inflating: dataset/Actor_24/03-01-08-02-02-01-24.wav
#   inflating: dataset/Actor_24/03-01-08-02-02-02-24.wav

# %%
pip install np_utils
# Out:
# Collecting np_utils
#   Downloading np_utils-0.6.0.tar.gz (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from np_utils) (2.0.2)
# Building wheels for collected packages: np_utils
#   Building wheel for np_utils (setup.py) ... done
#   Created wheel for np_utils: filename=np_utils-0.6.0-py3-none-any.whl size=56437 sha256=880f6f162abb126d11493b8e3049c92822b55a12ba8bb6d7eb5b56a855ba645f
#   Stored in directory: /root/.cache/pip/wheels/19/0d/33/eaa4dcda5799bcbb51733c0744970d10edb4b9add4f41beb43
# Successfully built np_utils
# Installing collected packages: np_utils
# Successfully installed np_utils-0.6.0

# %%
import pandas as pd
import numpy as np

import os
import sys

# librosa is a Python library for analyzing audio and music. It can be used to extract the data from the audio files we will see it later.
import librosa
import librosa.display
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split

# to play the audio files
from IPython.display import Audio

import keras
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential
from keras.layers import Dense, Conv1D, MaxPooling1D, Flatten, Dropout, BatchNormalization,LSTM
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint

import np_utils

import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning)


from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense,LSTM,Dropout,GRU,Bidirectional
import math

# %% [markdown]
# # Read sound files and pre-process

# %%
dataset_path = "./dataset/"
dataset_directory_list = os.listdir(dataset_path)
#dataset_directory_list= dataset_directory_list.sort()
file_emotion = []
file_path = []
print(dataset_directory_list)
for dir in dataset_directory_list:
    actor = os.listdir(dataset_path + dir)
    for file in actor:
        part = file.split('.')[0]
        part = part.split('-')
        file_emotion.append(int(part[2]))
        file_path.append(dataset_path + dir + '/' + file)
#print(file_emotion)
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])
path_df = pd.DataFrame(file_path, columns=['Path'])
dataset_df = pd.concat([emotion_df, path_df], axis=1)

dataset_df.Emotions.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
dataset_df.head()
# Out:
# ['Actor_24', 'Actor_16', 'Actor_20', 'Actor_13', 'Actor_23', 'Actor_08', 'Actor_15', 'Actor_10', 'Actor_02', 'Actor_21', 'Actor_14', 'Actor_19', 'Actor_07', 'Actor_01', 'Actor_03', 'Actor_17', 'Actor_11', 'Actor_06', 'Actor_18', 'Actor_05', 'Actor_04', 'Actor_09', 'Actor_12', 'Actor_22']
# <ipython-input-39-5f7cf1cbee8c>:19: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset_df.Emotions.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fear', 7:'disgust', 8:'surprise'}, inplace=True)
#   Emotions                                         Path
# 0  neutral  ./dataset/Actor_24/03-01-01-01-02-02-24.wav
# 1     calm  ./dataset/Actor_24/03-01-02-02-01-01-24.wav
# 2     calm  ./dataset/Actor_24/03-01-02-01-02-01-24.wav
# 3     calm  ./dataset/Actor_24/03-01-02-02-01-02-24.wav
# 4    happy  ./dataset/Actor_24/03-01-03-01-02-01-24.wav

# %%
dataset_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1440 entries, 0 to 1439
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Emotions  1440 non-null   object
#  1   Path      1440 non-null   object
# dtypes: object(2)
# memory usage: 22.6+ KB

# %%
dataset_df.describe()
# Out:
#        Emotions                                         Path
# count      1440                                         1440
# unique        8                                         1440
# top        calm  ./dataset/Actor_22/03-01-04-02-02-01-22.wav
# freq        192                                            1

# %%
# Emotion Count Graph
dataset_df.groupby('Emotions').size().plot(
    kind='barh',
    color=sns.palettes.mpl_palette('Set2')
)

plt.gca().spines[['top', 'right']].set_visible(False)
plt.xlabel("Count")
plt.title("Emotion Count")
plt.tight_layout()
plt.show()

# %%
def create_waveplot(data, sr, emotion):
    plt.figure(figsize=(12, 4), facecolor='#f5f5f5')
    plt.title(f'Waveplot for audio with {emotion} emotion', size=16)
    librosa.display.waveshow(data, sr=sr, color='teal')
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude')
    plt.tight_layout()
    plt.show()

def create_spectrogram(data, sr, emotion):
    X = librosa.stft(data)
    Xdb = librosa.amplitude_to_db(abs(X))
    plt.figure(figsize=(14, 4), facecolor='#f5f5f5')
    plt.title(f'Spectrogram for audio with {emotion} emotion', size=16)
    librosa.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='hz', cmap='magma')
    plt.colorbar(format='%+2.0f dB')
    plt.tight_layout()
    plt.show()

# %%
#  wavplot and spectogram a NORMAL sample

import matplotlib.pyplot as plt

emotion='neutral'
path = np.array(dataset_df.Path[dataset_df.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)

print(f"Sampling Rate: {sampling_rate}")

create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
# Sampling Rate: 22050
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# wavplot and spectogram a FEAR sample

import matplotlib.pyplot as plt

emotion='fear'
path = np.array(dataset_df.Path[dataset_df.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)

print(f"Sampling Rate: {sampling_rate}")

create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
# Sampling Rate: 22050
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# wavplot and spectogram a HAPPY sample

import matplotlib.pyplot as plt

emotion='happy'
path = np.array(dataset_df.Path[dataset_df.Emotions==emotion])[1]
data, sampling_rate = librosa.load(path)

print(f"Sampling Rate: {sampling_rate}")

create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
# Sampling Rate: 22050
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# wavplot and spectogram a ANGRY sample

import matplotlib.pyplot as plt

emotion='angry'
path = np.array(dataset_df.Path[dataset_df.Emotions==emotion])[1]
print(path)
data, sampling_rate = librosa.load(path)

print(f"Sampling Rate: {sampling_rate}")

create_waveplot(data, sampling_rate, emotion)
create_spectrogram(data, sampling_rate, emotion)
Audio(path)
# Out:
# ./dataset/Actor_24/03-01-05-01-01-02-24.wav
# Sampling Rate: 22050
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install soundfile
# Out:
# Requirement already satisfied: soundfile in /usr/local/lib/python3.11/dist-packages (0.13.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from soundfile) (2.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile) (2.22)

# %%
# !pip install noisereduce
# Out:
# Collecting noisereduce
#   Downloading noisereduce-3.0.3-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from noisereduce) (1.15.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from noisereduce) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from noisereduce) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from noisereduce) (4.67.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from noisereduce) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->noisereduce) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.17.0)
# Downloading noisereduce-3.0.3-py3-none-any.whl (22 kB)
# Installing collected packages: noisereduce
# Successfully installed noisereduce-3.0.3

# %%
Audio("./voice-with-background-noise.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import soundfile as sf
import noisereduce as nr

data, sr = librosa.load("./voice-with-background-noise.wav")

create_waveplot(data, sr, "NORMAL-NOISE")

data_denoised = nr.reduce_noise(data, sr)

# Save the denoised audio
sf.write('./denoised_audio.wav', data_denoised * 10, sr)

create_waveplot(data_denoised, sr, "NORMAL-DENOISED")

Audio("./denoised_audio.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# data augmentation functions

def denoise(data, sr):
    data = nr.reduce_noise(data, sr)
    return data

def noise(data):
    noise_amp = 0.035*np.random.uniform()*np.amax(data)
    data = data + noise_amp*np.random.normal(size=data.shape[0])
    return data

def stretch(data, rate=0.8):
    return librosa.effects.time_stretch(data, rate=rate)

def shift(data):
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)

def pitch(data, sampling_rate, pitch_factor=0.7):
    return librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=pitch_factor)

# taking any example and checking for techniques.
path = np.array(dataset_df.Path)[1]
data, sample_rate = librosa.load(path)
print(data,sample_rate)
# Out:
# [ 0.0000000e+00  0.0000000e+00  0.0000000e+00 ...  1.4387393e-07
#  -5.6013214e-08 -6.8287108e-08] 22050

# %%
# feature extraction fuctions

def extract_features(data):
    # ZCR
    result = np.array([])
    zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
    result=np.hstack((result, zcr)) # stacking horizontally

    # Chroma_stft
    stft = np.abs(librosa.stft(data))
    chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
    result = np.hstack((result, chroma_stft)) # stacking horizontally

    # MFCC
    mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mfcc)) # stacking horizontally

    # Root Mean Square Value
    rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
    result = np.hstack((result, rms)) # stacking horizontally

    # MelSpectogram
    mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)
    result = np.hstack((result, mel)) # stacking horizontally

    return result

def get_features(path):
    # duration and offset are used to take care of the no audio in start and the ending of each audio files as seen above.
    data, sample_rate = librosa.load(path, duration=2.5, offset=0.6)

    # without augmentation
    res1 = extract_features(data)
    result = np.array(res1)

    # data with noise
    noise_data = noise(data)
    res2 = extract_features(noise_data)
    result = np.vstack((result, res2)) # stacking vertically

    # data with stretching and pitching
    new_data = stretch(data)
    data_stretch_pitch = pitch(new_data, sample_rate)
    res3 = extract_features(data_stretch_pitch)
    result = np.vstack((result, res3)) # stacking vertically

    return result

# %%
X, Y = [], []
for path, emotion in zip(dataset_df.Path, dataset_df.Emotions):
    feature = get_features(path)
    for ele in feature:
        X.append(ele)
        # appending emotion 3 times as we have made 3 augmentation techniques on each audio file.
        Y.append(emotion)

# %%
# saving features into csv file
# !mkdir dataset_clean
Features = pd.DataFrame(X)
Features['labels'] = Y
Features.to_csv('./dataset_clean/features.csv', index=False)
Features.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.209314  0.491048  0.519866  0.540348  0.526163  0.500499  0.543318
# 1  0.278623  0.583559  0.579882  0.641618  0.635741  0.614903  0.613797
# 2  0.165354  0.537241  0.463775  0.545116  0.531292  0.528034  0.527584
# 3  0.172870  0.449521  0.459673  0.559358  0.571521  0.416510  0.438751
# 4  0.293217  0.616277  0.670225  0.744294  0.670417  0.635953  0.555835
#
#           7         8         9  ...           153           154  \
# 0  0.543232  0.572351  0.634695  ...  5.198969e-12  4.652095e-12
# 1  0.550110  0.543880  0.608905  ...  2.738273e-05  2.596305e-05
# 2  0.535643  0.507686  0.552384  ...  4.743061e-12  3.956251e-12
# 3  0.414743  0.550346  0.732046  ...  2.593764e-11  2.262233e-11
# 4  0.548954  0.702307  0.738098  ...  1.267213e-04  1.264443e-04
#
#             155           156           157           158           159  \
# 0  4.272559e-12  3.995306e-12  3.790897e-12  3.643169e-12  3.536236e-12
# 1  2.670670e-05  2.696401e-05  2.794753e-05  2.636349e-05  2.603285e-05
# 2  3.459108e-12  3.117198e-12  2.874368e-12  2.707473e-12  2.604789e-12
# 3  2.024632e-11  1.846408e-11  1.711493e-11  1.610874e-11  1.536500e-11
# 4  1.300232e-04  1.396518e-04  1.378444e-04  1.288791e-04  1.312025e-04
#
#             160           161   labels
# 0  3.465911e-12  3.422786e-12  neutral
# 1  2.559092e-05  2.703575e-05  neutral
# 2  2.073480e-12  8.420117e-13  neutral
# 3  1.485857e-11  1.455079e-11     calm
# 4  1.309611e-04  1.274279e-04     calm
#
# [5 rows x 163 columns]

# %%
X = Features.iloc[: ,:-1].values
Y = Features['labels'].values

# %%
# As this is a multiclass classification problem onehotencoding our Y.
encoder = OneHotEncoder()
Y = encoder.fit_transform(np.array(Y).reshape(-1,1)).toarray()

# %%
# splitting data
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=11, shuffle=True)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((3240, 162), (3240, 8), (1080, 162), (1080, 8))

# %%
# scaling our data with sklearn's Standard scaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((3240, 162), (3240, 8), (1080, 162), (1080, 8))

# %%
# making our data compatible to model.
x_train = np.expand_dims(x_train, axis=2)
x_test = np.expand_dims(x_test, axis=2)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((3240, 162, 1), (3240, 8), (1080, 162, 1), (1080, 8))

# %%
# creating model

model=Sequential()
model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu', input_shape=(x_train.shape[1], 1)))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(256, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Conv1D(128, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))
model.add(Dropout(0.2))

model.add(Conv1D(64, kernel_size=5, strides=1, padding='same', activation='relu'))
model.add(MaxPooling1D(pool_size=5, strides = 2, padding = 'same'))

model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(units=8, activation='softmax'))
model.compile(optimizer = 'adam' , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

model.summary()

print("\n\n next\n\n")

model1 = Sequential()
model1.add(LSTM(128, return_sequences=False, input_shape=(x_train.shape[1], 1)))
model1.add(Dense(units=64, activation='relu'))
model1.add(Dropout(0.4))
model1.add(Dense(units=32, activation='relu'))
model1.add(Dropout(0.4))
model1.add(Dense(units=8, activation='softmax'))

model1.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

model1.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 162, 256)       │         1,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 81, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 81, 256)        │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 41, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 41, 128)        │       163,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 21, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 21, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 21, 64)         │        41,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 11, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 704)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │        22,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 8)              │           264 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 557,288 (2.13 MB)
#  Trainable params: 557,288 (2.13 MB)
#  Non-trainable params: 0 (0.00 B)
#  next
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128)            │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 8)              │           264 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 77,160 (301.41 KB)
#  Trainable params: 77,160 (301.41 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#train model

rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)
history=model.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), callbacks=[rlrp])
print("\n\n next\n\n")
rlrp = ReduceLROnPlateau(monitor='loss', factor=0.4, verbose=0, patience=2, min_lr=0.0000001)
history=model1.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), callbacks=[rlrp])
# Out:
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 27s 532ms/step - accuracy: 0.8101 - loss: 0.5308 - val_accuracy: 0.5972 - val_loss: 1.3002 - learning_rate: 0.0010
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 28s 538ms/step - accuracy: 0.8203 - loss: 0.4853 - val_accuracy: 0.6306 - val_loss: 1.3373 - learning_rate: 0.0010
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 39s 504ms/step - accuracy: 0.8444 - loss: 0.4555 - val_accuracy: 0.6204 - val_loss: 1.3360 - learning_rate: 0.0010
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 23s 446ms/step - accuracy: 0.8304 - loss: 0.4999 - val_accuracy: 0.6056 - val_loss: 1.3526 - learning_rate: 0.0010
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 431ms/step - accuracy: 0.8359 - loss: 0.4688 - val_accuracy: 0.6130 - val_loss: 1.3726 - learning_rate: 0.0010
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 42s 458ms/step - accuracy: 0.8359 - loss: 0.4525 - val_accuracy: 0.6241 - val_loss: 1.3390 - learning_rate: 0.0010
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 40s 438ms/step - accuracy: 0.8551 - loss: 0.4029 - val_accuracy: 0.6157 - val_loss: 1.3833 - learning_rate: 0.0010
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 41s 431ms/step - accuracy: 0.8637 - loss: 0.4079 - val_accuracy: 0.6352 - val_loss: 1.3657 - learning_rate: 0.0010
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━
50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 23s 444ms/step - accuracy: 0.9618 - loss: 0.1192 - val_accuracy: 0.6639 - val_loss: 1.7762 - learning_rate: 4.0000e-04
# Epoch 30/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 42s 456ms/step - accuracy: 0.9726 - loss: 0.0978 - val_accuracy: 0.6759 - val_loss: 1.6616 - learning_rate: 1.6000e-04
# Epoch 31/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 39s 419ms/step - accuracy: 0.9719 - loss: 0.0972 - val_accuracy: 0.6815 - val_loss: 1.7741 - learning_rate: 1.6000e-04
# Epoch 32/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 40s 404ms/step - accuracy: 0.9673 - loss: 0.0930 - val_accuracy: 0.6750 - val_loss: 1.7773 - learning_rate: 1.6000e-04
# Epoch 33/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 45s 484ms/step - accuracy: 0.9734 - loss: 0.0806 - val_accuracy: 0.6806 - val_loss: 1.7814 - learning_rate: 1.6000e-04
# Epoch 34/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 40s 458ms/step - accuracy: 0.9726 - loss: 0.0849 - val_accuracy: 0.6778 - val_loss: 1.8100 - learning_rate: 1.6000e-04
# Epoch 35/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 40s 440ms/step - accuracy: 0.9721 - loss: 0.0947 - val_accuracy: 0.6685 - val_loss: 1.8069 - learning_rate: 1.6000e-04
# Epoch 36/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 40s 434ms/step - accuracy: 0.9742 - loss: 0.0807 - val_accuracy: 0.6833 - val_loss: 1.7943 - learning_rate: 6.4000e-05
# Epoch 37/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 42s 455ms/step - accuracy: 0.9718 - loss: 0.0968 - val_accuracy: 0.6824 - val_loss: 1.7795 - learning_rate: 6.4000e-05
# Epoch 38/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 427ms/step - accuracy: 0.9778 - loss: 0.0699 - val_accuracy: 0.6759 - val_loss: 1.8249 - learning_rate: 6.4000e-05
# Epoch 39/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 41s 436ms/step - accuracy: 0.9823 - loss: 0.0637 - val_accuracy: 0.6796 - val_loss: 1.8391 - learning_rate: 6.4000e-05
# Epoch 40/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 42s 454ms/step - accuracy: 0.9774 - loss: 0.0713 - val_accuracy: 0.6889 - val_loss: 1.8381 - learning_rate: 6.4000e-05
# Epoch 41/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 40s 427ms/step - accuracy: 0.9767 - loss: 0.0787 - val_accuracy: 0.6917 - val_loss: 1.8372 - learning_rate: 6.4000e-05
# Epoch 42/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 23s 459ms/step - accuracy: 0.9748 - loss: 0.0820 - val_accuracy: 0.6889 - val_loss: 1.8431 - learning_rate: 2.5600e-05
# Epoch 43/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 23s 454ms/step - accuracy: 0.9730 - loss: 0.0822 - val_accuracy: 0.6870 - val_loss: 1.8455 - learning_rate: 2.5600e-05
# Epoch 44/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 40s 440ms/step - accuracy: 0.9778 - loss: 0.0748 - val_accuracy: 0.6833 - val_loss: 1.8482 - learning_rate: 2.5600e-05
# Epoch 45/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 432ms/step - accuracy: 0.9750 - loss: 0.0842 - val_accuracy: 0.6880 - val_loss: 1.8495 - learning_rate: 2.5600e-05
# Epoch 46/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 42s 461ms/step - accuracy: 0.9739 - loss: 0.0753 - val_accuracy: 0.6861 - val_loss: 1.8569 - learning_rate: 1.0240e-05
# Epoch 47/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 40s 434ms/step - accuracy: 0.9741 - loss: 0.0728 - val_accuracy: 0.6898 - val_loss: 1.8499 - learning_rate: 1.0240e-05
# Epoch 48/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 435ms/step - accuracy: 0.9814 - loss: 0.0684 - val_accuracy: 0.6898 - val_loss: 1.8486 - learning_rate: 4.0960e-06
# Epoch 49/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 431ms/step - accuracy: 0.9840 - loss: 0.0623 - val_accuracy: 0.6889 - val_loss: 1.8487 - learning_rate: 4.0960e-06
# Epoch 50/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 41s 433ms/step - accuracy: 0.9797 - loss: 0.0689 - val_accuracy: 0.6880 - val_loss: 1.8509 - learning_rate: 4.0960e-06
#
#
#  next
#
#
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 326ms/step - accuracy: 0.1669 - loss: 2.0600 - val_accuracy: 0.2074 - val_loss: 1.9944 - learning_rate: 0.0010
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 301ms/step - accuracy: 0.1995 - loss: 1.9966 - val_accuracy: 0.1898 - val_loss: 1.9923 - learning_rate: 0.0010
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 318ms/step - accuracy: 0.2193 - loss: 1.9772 - val_accuracy: 0.2046 - val_loss: 1.9577 - learning_rate: 0.0010
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 297ms/step - accuracy: 0.2225 - loss: 1.9349 - val_accuracy: 0.2148 - val_loss: 1.9242 - learning_rate: 0.0010
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 298ms/step - accuracy: 0.2368 - loss: 1.9235 - val_accuracy: 0.1991 - val_loss: 1.9332 - learning_rate: 0.0010
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 318ms/step - accuracy: 0.2345 - loss: 1.9139 - val_accuracy: 0.2389 - val_loss: 1.8923 - learning_rate: 0.0010
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 320ms/step - accuracy: 0.2351 - loss: 1.8885 - val_accuracy: 0.2287 - val_loss: 1.8801 - learning_rate: 0.0010
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 319ms/step - accuracy: 0.2295 - loss: 1.8911 - val_accuracy: 0.1954 - val_loss: 1.9533 - learning_rate: 0.0010
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 321ms/step - accuracy: 0.2143 - loss: 1.9480 - val_accuracy: 0.2074 - val_loss: 1.9368 - learning_rate: 0.0010
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 301ms/step - accuracy: 0.2357 - loss: 1.9232 - val_accuracy: 0.2296 - val_loss: 1.8930 - learning_rate: 4.0000e-04
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 320ms/step - accuracy: 0.2561 - loss: 1.8767 - val_accuracy: 0.2444 - val_loss: 1.8515 - learning_rate: 4.0000e-04
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 317ms/step - accuracy: 0.2449 - loss: 1.8697 - val_accuracy: 0.2481 - val_loss: 1.8551 - learning_rate: 4.0000e-04
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 299ms/step - accuracy: 0.2563 - loss: 1.8358 - val_accuracy: 0.2417 - val_loss: 1.8576 - learning_rate: 4.0000e-04
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 317ms/step - accuracy: 0.2498 - loss: 1.8710 - val_accuracy: 0.2500 - val_loss: 1.8387 - learning_rate: 4.0000e-04
# Epoch 15/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 300ms/step - accuracy: 0.2548 - loss: 1.8423 - val_accuracy: 0.2435 - val_loss: 1.8644 - learning_rate: 4.0000e-04
# Epoch 16/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 302ms/step - accuracy: 0.2532 - loss: 1.8521 - val_accuracy: 0.2583 - val_loss: 1.8424 - learning_rate: 4.0000e-04
# Epoch 17/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 315ms/step - accuracy: 0.2723 - loss: 1.8185 - val_accuracy: 0.2398 - val_loss: 1.8548 - learning_rate: 4.0000e-04
# Epoch 18/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 314ms/step - accuracy: 0.2532 - loss: 1.8534 - val_accuracy: 0.2667 - val_loss: 1.8311 - learning_rate: 4.0000e-04
# Epoch 19/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 317ms/step - accuracy: 0.2660 - loss: 1.8249 - val_accuracy: 0.2639 - val_loss: 1.8443 - learning_rate: 4.0000e-04
# Epoch 20/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 316ms/step - accuracy: 0.2714 - loss: 1.8353 - val_accuracy: 0.2620 - val_loss: 1.8487 - learning_rate: 4.0000e-04
# Epoch 21/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 324ms/step - accuracy: 0.2761 - loss: 1.8240 - val_accuracy: 0.2602 - val_loss: 1.8490 - learning_rate: 4.0000e-04
# Epoch 22/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 304ms/step - accuracy: 0.2774 - loss: 1.8038 - val_accuracy: 0.2574 - val_loss: 1.8626 - learning_rate: 4.0000e-04
# Epoch 23/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 317ms/step - accuracy: 0.2639 - loss: 1.8327 - val_accuracy: 0.2731 - val_loss: 1.8186 - learning_rate: 4.0000e-04
# Epoch 24/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 319ms/step - accuracy: 0.2754 - loss: 1.8074 - val_accuracy: 0.2787 - val_loss: 1.8229 - learning_rate: 4.0000e-04
# Epoch 25/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 310ms/step - accuracy: 0.2985 - loss: 1.8141 - val_accuracy: 0.2694 - val_loss: 1.8276 - learning_rate: 1.6000e-04
# Epoch 26/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 317ms/step - accuracy: 0.2642 - loss: 1.8080 - val_accuracy: 0.2713 - val_loss: 1.8041 - learning_rate: 1.6000e-04
# Epoch 27/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 19s 297ms/step - accuracy: 0.2823 - loss: 1.7861 - val_accuracy: 0.2898 - val_loss: 1.7989 - learning_rate: 1.6000e-04
# Epoch 28/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 319ms/step - accuracy: 0.2762 - loss: 1.7979 - val_accuracy: 0.2722 - val_loss: 1.8303 - learning_rate: 1.6000e-04
# Epoch 29/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 319ms/step - accuracy: 0.2697 - loss: 1.7929 - val_accuracy: 0.2861 - val_loss: 1.8021 - learning_rate: 1.6000e-04
# Epoch 30/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 317ms/step - accuracy: 0.2729 - loss: 1.7924 - val_accuracy: 0.2935 - val_loss: 1.8028 - learning_rate: 1.6000e-04
# Epoch 31/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 301ms/step - accuracy: 0.2822 - loss: 1.7925 - val_accuracy: 0.2972 - val_loss: 1.7962 - learning_rate: 1.6000e-04
# Epoch 32/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 301ms/step - accuracy: 0.2861 - loss: 1.7861 - val_accuracy: 0.2787 - val_loss: 1.7966 - learning_rate: 1.6000e-04
# Epoch 33/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 316ms/step - accuracy: 0.2928 - loss: 1.7797 - val_accuracy: 0.2741 - val_loss: 1.8075 - learning_rate: 1.6000e-04
# Epoch 34/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 317ms/step - accuracy: 0.2890 - loss: 1.7735 - val_accuracy: 0.2944 - val_loss: 1.7931 - learning_rate: 1.6000e-04
# Epoch 35/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 302ms/step - accuracy: 0.2751 - loss: 1.7836 - val_accuracy: 0.3019 - val_loss: 1.7968 - learning_rate: 1.6000e-04
# Epoch 36/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 306ms/step - accuracy: 0.2887 - loss: 1.7740 - val_accuracy: 0.2880 - val_loss: 1.7896 - learning_rate: 1.6000e-04
# Epoch 37/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 332ms/step - accuracy: 0.2987 - loss: 1.7719 - val_accuracy: 0.2917 - val_loss: 1.7880 - learning_rate: 1.6000e-04
# Epoch 38/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 24s 399ms/step - accuracy: 0.2848 - loss: 1.7842 - val_accuracy: 0.2574 - val_loss: 1.8559 - learning_rate: 1.6000e-04
# Epoch 39/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 307ms/step - accuracy: 0.2675 - loss: 1.8133 - val_accuracy: 0.2898 - val_loss: 1.7950 - learning_rate: 6.4000e-05
# Epoch 40/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 298ms/step - accuracy: 0.2931 - loss: 1.7596 - val_accuracy: 0.2889 - val_loss: 1.7918 - learning_rate: 6.4000e-05
# Epoch 41/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 319ms/step - accuracy: 0.2850 - loss: 1.7702 - val_accuracy: 0.2907 - val_loss: 1.7942 - learning_rate: 2.5600e-05
# Epoch 42/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 299ms/step - accuracy: 0.2876 - loss: 1.7700 - val_accuracy: 0.2981 - val_loss: 1.7890 - learning_rate: 2.5600e-05
# Epoch 43/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 299ms/step - accuracy: 0.2911 - loss: 1.7641 - val_accuracy: 0.2963 - val_loss: 1.7871 - learning_rate: 2.5600e-05
# Epoch 44/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 22s 332ms/step - accuracy: 0.2861 - loss: 1.7657 - val_accuracy: 0.2944 - val_loss: 1.7872 - learning_rate: 1.0240e-05
# Epoch 45/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 310ms/step - accuracy: 0.2860 - loss: 1.7728 - val_accuracy: 0.2963 - val_loss: 1.7889 - learning_rate: 1.0240e-05
# Epoch 46/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 16s 321ms/step - accuracy: 0.2946 - loss: 1.7593 - val_accuracy: 0.2991 - val_loss: 1.7880 - learning_rate: 1.0240e-05
# Epoch 47/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 309ms/step - accuracy: 0.2794 - loss: 1.7696 - val_accuracy: 0.2981 - val_loss: 1.7872 - learning_rate: 4.0960e-06
# Epoch 48/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 20s 302ms/step - accuracy: 0.3019 - loss: 1.7729 - val_accuracy: 0.2954 - val_loss: 1.7873 - learning_rate: 4.0960e-06
# Epoch 49/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 15s 303ms/step - accuracy: 0.3026 - loss: 1.7563 - val_accuracy: 0.2963 - val_loss: 1.7873 - learning_rate: 1.6384e-06
# Epoch 50/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 21s 320ms/step - accuracy: 0.2954 - loss: 1.7471 - val_accuracy: 0.3000 - val_loss: 1.7871 - learning_rate: 1.6384e-06

# %%
# test model

print("Accuracy of our model on test data : " , model.evaluate(x_test,y_test)[1]*100 , "%")

epochs = [i for i in range(50)]
fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
test_acc = history.history['val_accuracy']
test_loss = history.history['val_loss']

fig.set_size_inches(18,8)
ax[0].plot(epochs , train_loss , label = 'Training Loss')
ax[0].plot(epochs , test_loss , label = 'Testing Loss')
ax[0].set_title('Training & Testing Loss')
ax[0].legend()
ax[0].set_xlabel("Epochs")

ax[1].plot(epochs , train_acc , label = 'Training Accuracy')
ax[1].plot(epochs , test_acc , label = 'Testing Accuracy')
ax[1].set_title('Training & Testing Accuracy')
ax[1].legend()
ax[1].set_xlabel("Epochs")
plt.show()
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.6771 - loss: 1.8738
# Accuracy of our model on test data :  68.79629492759705 %

# %%
# predicting on test data.
pred_test = model.predict(x_test)
y_pred = encoder.inverse_transform(pred_test)

y_test = encoder.inverse_transform(y_test)
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step

# %%
df = pd.DataFrame(columns=['Predicted Labels', 'Actual Labels'])
df['Predicted Labels'] = y_pred.flatten()
df['Actual Labels'] = y_test.flatten()

df.head(10)
# Out:
#   Predicted Labels Actual Labels
# 0            happy       disgust
# 1             fear          fear
# 2             calm          calm
# 3              sad           sad
# 4              sad          calm
# 5            angry      surprise
# 6             calm       neutral
# 7              sad         happy
# 8             calm          fear
# 9         surprise         happy

# %%
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize = (14, 10))
cm = pd.DataFrame(cm , index = [i for i in encoder.categories_] , columns = [i for i in encoder.categories_])
sns.heatmap(cm, linecolor='white', cmap='Blues', linewidth=1, annot=True, fmt='')
plt.title('Confusion Matrix', size=18)
plt.xlabel('Predicted Labels', size=12)
plt.ylabel('Actual Labels', size=12)
plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        angry       0.75      0.70      0.72       138
#         calm       0.76      0.85      0.80       133
#      disgust       0.66      0.66      0.66       134
#         fear       0.73      0.70      0.71       151
#        happy       0.61      0.61      0.61       144
#      neutral       0.40      0.45      0.42        69
#          sad       0.66      0.71      0.68       147
#     surprise       0.79      0.71      0.75       164
#
#     accuracy                           0.69      1080
#    macro avg       0.67      0.67      0.67      1080
# weighted avg       0.69      0.69      0.69      1080
